# %%
l=['apple',20,[2,6,8],('a','b','c')]
print(l)

l.append('banana')
print(l)

l.insert(3,76)
print(l)

l.pop()
print(l)

l.remove(20)
print(l)

l.reverse()
print(l)
# Out:
# ['apple', 20, [2, 6, 8], ('a', 'b', 'c')]
# ['apple', 20, [2, 6, 8], ('a', 'b', 'c'), 'banana']
# ['apple', 20, [2, 6, 8], 76, ('a', 'b', 'c'), 'banana']
# ['apple', 20, [2, 6, 8], 76, ('a', 'b', 'c')]
# ['apple', [2, 6, 8], 76, ('a', 'b', 'c')]
# [('a', 'b', 'c'), 76, [2, 6, 8], 'apple']
