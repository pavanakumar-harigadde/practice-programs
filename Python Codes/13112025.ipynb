# %%
import sys
sys.argv = ['add_numbers.py','10','20']
x =int(sys.argv[1])
y =int(sys.argv[2])
print("sum",x+y)
# Out:
# sum 30

# %%
import sys
age=10
if age<18:
    print("Eligible")
else:
    print("Not eligibe")
# Out:
# Eligible

# %%
loaded_modules
