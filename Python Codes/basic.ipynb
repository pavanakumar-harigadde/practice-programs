# %%
print("Hello there! Welcome to Pavanakumar's account.")
# Out:
# Hello there! Welcome to Pavanakumar's account.

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
