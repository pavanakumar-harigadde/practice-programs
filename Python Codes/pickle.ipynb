# %%
import pickle

# %%
my_list = ['apple', 'banana', 'cherry']
with open('list.pkl', 'wb') as file :
    pickle.dump(my_list, file)
with open('list.pkl', 'rb') as file :
    loaded_list = pickle.load(file)
print("Loaded List: ", loaded_list)
# Out:
# Loaded List:  ['apple', 'banana', 'cherry']

# %%
my_dict = {'name':'Madesha', 'Age': 25, 'address':'Bengaluru'}
with open('dict.pkl', 'wb') as file :
    pickle.dump(my_dict, file)
with open('dict.pkl', 'rb') as file :
    loaded_dict = pickle.load(file)
print("Loaded Dictionary: ", loaded_dict)
# Out:
# Loaded Dictionary:  {'name': 'Madesha', 'Age': 25, 'address': 'Bengaluru'}
