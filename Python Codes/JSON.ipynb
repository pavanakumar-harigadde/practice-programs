# %%
import json
data = {"Barty":
        {
            "number":"+61 2 3617 9451",
            "age": 50,
            "address": [
                "10/365 Pacific Highway",
                "Hornsby",
                "New South Wales",
                "Australia",
                "2017"
            ]
        },

        "Molly":
        {
            "number":"+91 9945451546",
            "age": 45,
            "address": [
                "Ottery St Catchpole",
                "Devon",
                "London",
                "UK",
                "4597"
            ]
        }
       }
